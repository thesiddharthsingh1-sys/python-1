# %%
# List Operations

my_list = [40, 10, 30, 20, 50]

print("Original List:", my_list)

my_list.append(60)
print("After append:", my_list)

my_list.insert(2, 25)
print("After insert:", my_list)

my_list.remove(30)
print("After remove:", my_list)

my_list.pop()
print("After pop:", my_list)

my_list.sort()
print("After sort:", my_list)


# Tuple Operations

my_tuple = (10, 20, 30, 20, 40, 50)

print("\nOriginal Tuple:", my_tuple)

print("Count of 20:", my_tuple.count(20))

print("Index of 30:", my_tuple.index(30))

print("Length of Tuple:", len(my_tuple))

print("Maximum element:", max(my_tuple))

print("Minimum element:", min(my_tuple))


# Dictionary Operations

student = {
    "name": "Rahul",
    "age": 18,
    "branch": "CSE",
    "year": 1
}

print("\nOriginal Dictionary:", student)

print("Keys:", student.keys())

print("Values:", student.values())

print("Items:", student.items())

print("Name:", student.get("name"))

student.pop("age")
print("After removing age:", student)
# Out:
# Original List: [40, 10, 30, 20, 50]
# After append: [40, 10, 30, 20, 50, 60]
# After insert: [40, 10, 25, 30, 20, 50, 60]
# After remove: [40, 10, 25, 20, 50, 60]
# After pop: [40, 10, 25, 20, 50]
# After sort: [10, 20, 25, 40, 50]
#
# Original Tuple: (10, 20, 30, 20, 40, 50)
# Count of 20: 2
# Index of 30: 2
# Length of Tuple: 6
# Maximum element: 50
# Minimum element: 10
#
# Original Dictionary: {'name': 'Rahul', 'age': 18, 'branch': 'CSE', 'year': 1}
# Keys: dict_keys(['name', 'age', 'branch', 'year'])
# Values: dict_values(['Rahul', 18, 'CSE', 1])
# Items: dict_items([('name', 'Rahul'), ('age', 18), ('branch', 'CSE'), ('year', 1)])
# Name: Rahul
# After removing age: {'name': 'Rahul', 'branch': 'CSE', 'year': 1}
