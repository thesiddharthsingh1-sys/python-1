# %%
def greet():
    print("Hello, World!")

greet()


# 2. Is it Mandatory for a Python Function to Return a Value?

# No, it is not mandatory.
# A function can perform a task without returning a value.

def add(a, b):
    print(a + b)

add(10, 20)

# A function can also return a value.

def multiply(a, b):
    return a * b

result = multiply(5, 4)
print(result)


# 3. Some Standard Python Error
