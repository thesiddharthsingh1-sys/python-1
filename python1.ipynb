# %%
# Q1
a = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(a[::2])


# Q2
l = [1, 2, 3]
init_tuple = ('Python',) * (l.__len__() - l[::-1][0])
print(init_tuple)


# Q3
# List
my_list = [1, 2, 3]

# Tuple
my_tuple = (1, 2, 3)

# Dictionary
my_dict = {"a": 1, "b": 2, "c": 3}

print(my_list)
print(my_tuple)
print(my_dict)
